# %% [markdown]
# Q1. What is the relationship between classes and modules?
#
# Ans: Classes and modules are collection of methods and attributes but, instance of class can be created but it cannot be created for a module.
#
#
#
# Q2. How do you make instances and classes?
#
# Ans:class classname:
#         pass
#
#      obj=classname()
#
#
#
# Q3. Where and how should be class attributes created?
#
# Ans:It is created within class , not inside any method
# example:
# class Marks:
#     id=123
#     name='Prachi'
# Here Marks is class and id and name are class attributes
#
#
#
# Q4. Where and how are instance attributes created?
#
# Ans: They are created inside constructor using self.
#
#
#
# Q5. What does the term "self" in a Python class mean?
#
# Ans: self is nota keyword,we can use any other name but it is used to link variables and methods to that class.
#
#
#
# Q6. How does a Python class handle operator overloading?
#
# Ans. Overloading is done by having more than one method with same name but different no of attributes or different output.
#
#
#
# Q7. When do you consider allowing operator overloading of your classes?
#
# Ans. Operator overloading is done when one operator can function in multiple ways example: + can be used to add 2 integers or to concatenate 2 strings.
#
#
# Q8. What is the most popular form of operator overloading?
#
# Ans: + can be used to add 2 integers or to concatenate 2 strings.
#
#
#
# Q9. What are the two most important concepts to grasp in order to comprehend Python OOP code?
#
# Ans: Inheritance and polymorphism
